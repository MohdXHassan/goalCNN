# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
f,ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 4, 2],[1, 2, 3])
 # Plot some data on the axes.

# %%
  # Plot some data on the axes.
f,ax = plt.subplots() 
ax.plot([1, 2, 3, 4],[1, 4, 2, 3])

# %%
plt.show()

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(1,1)  # a figure with a 2x2 grid of Axes
# # a figure with one axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left_top', 'right'],
                               ['left_bottom', 'right']])

# %%
y=[]
for i in range(-10,10,1):
    y.append(i**2)
f,x = plt.subplots()  # Create a figure containing a single axes.
x.plot(y)
 # Plot some data on the axes.
